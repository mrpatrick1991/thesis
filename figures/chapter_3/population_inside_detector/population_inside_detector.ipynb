# %%
import glob
import numpy as np
import matplotlib.pyplot as plt
from natsort import natsorted
# %matplotlib inline

plt.rcParams['mathtext.fontset'] = 'stix'
plt.rcParams['font.family'] = 'STIXGeneral'
plt.rc('font', size=12) 
# %config InlineBackend.figure_format = 'svg'

# %%
path = '/Users/patrick/Documents/phd/GitHub/tikhonov/'

g4_on = np.zeros(2000)
g4on =  np.loadtxt(open("with.csv", "r"), delimiter=",",skiprows=9)[:,3]

g4_off = np.zeros(2000)
g4off =  np.loadtxt(open("without.csv", "r"), delimiter=",",skiprows=9)[:,3]

# %%
fig = plt.figure(figsize=(6.52437527778,4.5))
gs = plt.GridSpec(nrows=1, ncols=1,hspace=.3)
ax = fig.add_subplot(gs[0, 0])

ax.plot(g4off/np.max(g4off),'.',color='lightgrey',label="Detector Materials Off")
ax.plot(g4on/np.max(g4off),'.',label="Detector Materials On")

ax.set_xlabel("photon polar angle (degrees)")
ax.set_ylabel("photon count (normalized)")
ax.legend()

fig.savefig("population_inside_detector.pdf")
